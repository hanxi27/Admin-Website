# %% [markdown]
# <a href="https://colab.research.google.com/github/hanxi27/Admin-Website/blob/main/HanxiFYP1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/hanxi27/FYP-SkyGPT.git
# Out:
# Cloning into 'FYP-SkyGPT'...
# fatal: could not read Username for 'https://github.com': No such device or address

# %% [markdown]
# # New Section

# %%
import os
from datetime import datetime,timedelta
import cv2
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import shutil
import random
import requests
from bs4 import BeautifulSoup
import urllib
import matplotlib.dates as mdates

# %% [markdown]
# # New Section

# %%
path="/content/drive/MyDrive/FYP1Dataset/20230901.csv"
df=pd.read_csv(path)
df.head(10)
# Out:
#   DATE (MM/DD/YYYY)    MST  Global CMP22 (vent/cor) [W/m^2]  \
# 0          9/1/2023  05:31                          4.89306
# 1          9/1/2023  05:32                          4.99848
# 2          9/1/2023  05:33                          5.18588
# 3          9/1/2023  05:34                          5.48784
# 4          9/1/2023  05:35                          5.73921
# 5          9/1/2023  05:36                          6.23529
# 6          9/1/2023  05:37                          7.68934
# 7          9/1/2023  05:38                          9.73746
# 8          9/1/2023  05:39                         10.53730
# 9          9/1/2023  05:40                          9.72901
#
#    Zenith Angle [degrees]  Azimuth Angle [degrees]
# 0                89.94254                 78.90136
# 1                89.77880                 79.06161
# 2                89.61363                 79.22174
# 3                89.44689                 79.38176
# ...
